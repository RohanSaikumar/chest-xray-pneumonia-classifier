# %%
import os

project_name = "chest-xray-covid-classifier"

folders = [
    project_name,
    f"{project_name}/src",
    f"{project_name}/notebooks"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

os.listdir(project_name)
# Out:
# ['notebooks', 'src']

# %%
# !mv Untitled3.ipynb chest-xray-covid-classifier/notebooks/exploration.ipynb
# Out:
# mv: cannot stat 'Untitled3.ipynb': No such file or directory

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# chest-xray-covid-classifier  sample_data

# %%
# !find /content -name "*.ipynb"
